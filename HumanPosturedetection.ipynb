# %% [markdown]
# <a href="https://colab.research.google.com/github/KartavyaManiar/Deep-Learning-Projects/blob/main/HumanPosturedetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install mediapipe

# %%
# !pip install opencv-python==4.8.1.78
# !pip install mediapipe==0.10.8

# %%
import cv2
import mediapipe as mp

# %%
## initialize pose estimator
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cap = cv2.VideoCapture('test_video.mp4')
while cap.isOpened():
    # read frame
    _, frame = cap.read()
    try:
        # resize the frame for portrait video
        frame = cv2.resize(frame, (350, 600))
        # convert to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # process the frame for pose detection
        pose_results = pose.process(frame_rgb)
        # print(pose_results.pose_landmarks)

        # draw skeleton on the frame
        mp_drawing.draw_landmarks(frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        # display the frame
        cv2.imshow('Output', frame)
    except:
        break

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# access pose results within the loop

cap = cv2.VideoCapture('test_video.mp4')
while cap.isOpened():
    # read frame
    _, frame = cap.read()
    try:
        # resize the frame for portrait video
        frame = cv2.resize(frame, (350, 600))
        # convert to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # process the frame for pose detection
        pose_results = pose.process(frame_rgb)
        # print(pose_results.pose_landmarks)

        # draw skeleton on the frame
        mp_drawing.draw_landmarks(frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        # access pose_results here within the loop
        # get landmark for a specific point
        print(pose_results.pose_landmarks.landmark[32])

        # display the frame
        cv2.imshow('Output', frame)
    except:
        break

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# access pose results within the loop

cap = cv2.VideoCapture('test_video.mp4')
while cap.isOpened():
    # read frame
    _, frame = cap.read()
    try:
        # resize the frame for portrait video
        frame = cv2.resize(frame, (350, 600))
        # convert to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # process the frame for pose detection
        pose_results = pose.process(frame_rgb)
        # print(pose_results.pose_landmarks)

        # draw skeleton on the frame
        mp_drawing.draw_landmarks(frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        # access pose_results here within the loop
        # get landmark for a specific point
        if pose_results.pose_landmarks:
            print(pose_results.pose_landmarks.landmark[32])

        # display the frame
        cv2.imshow('Output', frame)
    except:
        break

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import mediapipe as mp

# initialize pose estimator
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

cap = cv2.VideoCapture('test_video.mp4')
landmark_data = None  # Variable to store landmark data

while cap.isOpened():
    # read frame
    _, frame = cap.read()
    try:
        # resize the frame for portrait video
        frame = cv2.resize(frame, (350, 600))
        # convert to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # process the frame for pose detection
        pose_results = pose.process(frame_rgb)

        # draw skeleton on the frame
        mp_drawing.draw_landmarks(frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        # Store landmark data if available
        if pose_results.pose_landmarks:
            landmark_data = pose_results.pose_landmarks.landmark[32]

        # display the frame
        cv2.imshow('Output', frame)
    except:
        break

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# Access landmark data after the loop
if landmark_data:
    print(landmark_data)

# %% [markdown]
# ![Ai  work 2.webp](data:image/webp;base64,...)

# %%
import cv2
import mediapipe as mp

# initialize pose estimator
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

cap
# Out:
# < cv2.VideoCapture 0x7d943fda89f0>

# %%
import cv2
import mediapipe as mp

# initialize pose estimator
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

cap = cv2.VideoCapture('test_video.mp4')
landmark_data = None

# %%
import cv2
import mediapipe as mp

# Initialize pose estimator
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Load the image
# Ensure the image exists and the path is correct
image = cv2.imread("image.jpg")

# Check if the image was loaded correctly
if image is not None:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Process the image for pose detection
    results = pose.process(image_rgb)

    # Check if pose landmarks were detected
    if results.pose_landmarks:
        # Get landmark coordinates and assign to a dictionary
        landmarks = {}
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            landmarks[idx + 1] = (landmark.x, landmark.y)

        print(landmarks) # Print landmark coordinates

# Close the pose estimator
pose.close()
else:
    print("Error: Could not load image.")

# %%
import cv2
import mediapipe as mp

# Initialize pose estimator
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

cap = cv2.VideoCapture('test_video.mp4')

while cap.isOpened():
    # Read frame
    _, frame = cap.read()
    try:
        # Resize the frame for portrait video
        frame = cv2.resize(frame, (350, 600))
        # Convert to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the frame for pose detection
        pose_results = pose.process(frame_rgb)

        # Draw skeleton on the frame
        mp_drawing.draw_landmarks(frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        # Access and store specific landmark data
        if pose_results.pose_landmarks:
            right_hip_x = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].x
            right_hip_y = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].y
            right_hip_z = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].z

            # Access and store data for other landmarks as needed
            # For example:
            # left_shoulder_x = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER].x
            # ... and so on

        # Display the frame
        cv2.imshow('Output', frame)
    except:
        break

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
print(f"Right hip x-coordinate: {right_hip_x}")

# Print the extracted landmark data
print(f"Right Hip x: {right_hip_x}, y: {right_hip_y}, z: {right_hip_z}")
# Print other landmark data as needed
# Out:
# Right hip x-coordinate: None
# Right Hip x: None, y: None, z: None

# %%
import cv2
import mediapipe as mp

# Initialize pose estimator
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

cap = cv2.VideoCapture('test_video.mp4')

# Initialize landmark variables before the loop
right_hip_x = right_hip_y = right_hip_z = None

while cap.isOpened():
    # Read frame
    _, frame = cap.read()
    try:
        # Resize the frame for portrait video
        frame = cv2.resize(frame, (350, 600))
        # Convert to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Process the frame for pose detection
        pose_results = pose.process(frame_rgb)

        # Draw skeleton on the frame
        mp_drawing.draw_landmarks(frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        # Access and store specific landmark data
        if pose_results.pose_landmarks:
            right_hip_x = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].x
            right_hip_y = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].y
            right_hip_z = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.RIGHT_HIP].z

            # Access and store data for other landmarks as needed
            # For example:
            # left_shoulder_x = pose_results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_SHOULDER].x
            # ... and so on

        # Display the frame
        cv2.imshow('Output', frame)
    except:
        break

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# Check if landmark data was captured before printing
if right_hip_x is not None:
    print(f"Right hip x-coordinate: {right_hip_x}")

    # Print the extracted landmark data
    print(f"Right Hip x: {right_hip_x}, y: {right_hip_y}, z: {right_hip_z}")
# Print other landmark data as needed

# %%
import cv2
import mediapipe as mp

# Initialize pose estimator
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Load the image
# Use the correct file path and verify the image exists
image = cv2.imread("test_image.jpg")

# Check if the image loaded correctly
if image is None:
    print("Error: Could not load image. Please check the file path.")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Process the image for pose detection
    results = pose.process(image_rgb)

    # Check if pose landmarks were detected
    if results.pose_landmarks:
        # Get landmark coordinates and assign to a dictionary
        landmarks = {}
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            landmarks[idx + 1] = (landmark.x, landmark.y)

        print(landmarks) # Print landmark coordinates

    # Close the pose estimator
    pose.close()
# Out:
# Error: Could not load image. Please check the file path.

# %%
import cv2
import mediapipe as mp

# Initialize pose estimator
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Load the image
image = cv2.imread("test_image.jpg")

# Check if the image loaded correctly
if image is None:
    print("Error: Could not load image. Please check the file path.")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Process the image for pose detection
    results = pose.process(image_rgb)

    # Check if pose landmarks were detected
    if results.pose_landmarks:
        # Get landmark coordinates and assign to a dictionary with labels
        landmarks = {}
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            landmarks[mp_pose.PoseLandmark(idx).name] = (landmark.x, landmark.y, landmark.z)

        print(landmarks) # Print landmark coordinates with labels

    # Close the pose estimator
    pose.close()
# Out:
# Error: Could not load image. Please check the file path.

# %%
x: 0.35414522886276245
y: 0.8367241024971008
z: 0.16406674683094025
visibility: 0.9696751236915588

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    # read frame
    _, frame = cap.read()
    try:
        # resize the frame for portrait video
        # frame = cv2.resize(frame, (350, 600))
        # convert to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # process the frame for pose detection
        pose_results = pose.process(frame_rgb)
        # print(pose_results.pose_landmarks)

        # draw skeleton on the frame
        mp_drawing.draw_landmarks(frame, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        # display the frame
        cv2.imshow('Output', frame)
    except:
        break

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
